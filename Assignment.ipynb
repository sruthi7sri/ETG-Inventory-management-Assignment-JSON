# %%
import json

# %%
data = open("record.json",'r')
rec = data.read()
data.close()

records = json.loads(rec)

# %%
records
# Out:
# {'1001': {'Name': 'Product1',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1002': {'Name': 'Product2',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1003': {'Name': 'Product3',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1004': {'Name': 'Product4',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1005': {'Name': 'Product5',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1006': {'Name': 'Product6',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1007': {'Name': 'Product7',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1008': {'Name': 'Product8',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1009': {'Name': 'Product9',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1010': {'Name': 'Product10',
#   'MRP': 1500,
#   'Quantity': 8,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1011': {'Name': 'Product11',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1012': {'Name': 'Product12',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1013': {'Name': 'Product13',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1014': {'Name': 'Product14',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1015': {'Name': 'Product15',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1016': {'Name': 'Product16',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1017': {'Name': 'Product17',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1018': {'Name': 'Product18',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1019': {'Name': 'Product19',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1020': {'Name': 'Product20',
#   'MRP': 1500,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1021': {'Name': 'Product21',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1022': {'Name': 'Product22',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1023': {'Name': 'Product23',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1024': {'Name': 'Product24',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1025': {'Name': 'Product25',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1026': {'Name': 'Product26',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1027': {'Name': 'Product27',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1028': {'Name': 'Product28',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1029': {'Name': 'Product29',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1030': {'Name': 'Product30',
#   'MRP': 1500,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1}}

# %%
#TO ORDER PRODUCT

prod_ID  = str(input("Enter the product_Id: "))
Quantity= int(input("Enter the quantity: "))


print("Your Product: ", records[prod_ID]['Name'])
print("Product MRP: ", records[prod_ID]['MRP'])
print("Your Billing Amount: ", records[prod_ID]['MRP'] * Quantity)

records[prod_ID]['Quantity'] = records[prod_ID]['Quantity'] - Quantity 
print(records[prod_ID]['Quantity'])
# Out:
# Enter the product_Id: 1011
# Enter the quantity: 4
# Your Product:  Product11
# Product MRP:  100
# Your Billing Amount:  400
# 30

# %%
RemainingProduct = records[prod_ID]['Quantity'] - Q

# %%
#TO STORE ORDERED PRODUCT DETAILS

js = json.dumps(records)

data = open("record.json",'w')
data.write(js)
data.close()

# %%
{'Product' : prod_ID, 'Quantity' : Quantity, 'Amount': records[prod_ID]['MRP'] * Quantity}
# Out:
# {'Product': '1011', 'Quantity': 4, 'Amount': 400}

# %%
#To update Quantity

data = open("record.json",'w')
data.write(js)
data.close()

# %%
sales = {1 : {'Product' : prod_ID, 'Remaining Quantity' : records[prod_ID]['Quantity'], 'Amount': records[prod_ID]['MRP'] * quantity},}
print("Remaining Quantity of ordered product:")
sales
# Out:
# Remaining Quantity of ordered product:
# {1: {'Product': '1011', 'Remaining Quantity': 30, 'Amount': 1000}}

# %%
#FOR ADMIN TO ADD A NEW PRODUCT

prod_ID = str(input("Enter product id:"))
name = str(input("Enter name:"))
MRP = int(input("Enter price:"))
Quantity = int(input("Enter quantity:"))
Category = str(input("Enter product category, e.g., Food,stationary,etc:"))
Minimum_Order_Quantity = int(input("Enter minimum order quantity:"))


records[prod_ID] = {'Name': name, 'MRP': MRP, 'Quantity': Quantity, "Category": Category, "Minimum_Order": Minimum_Order_Quantity}

js = json.dumps(records)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1031
# Enter name:Product31
# Enter price:250
# Enter quantity:100
# Enter product category, e.g., Food,stationary,etc:Food
# Enter minimum order quantity:1

# %%
records
# Out:
# {'1001': {'Name': 'Product1',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1002': {'Name': 'Product2',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1003': {'Name': 'Product3',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1004': {'Name': 'Product4',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1005': {'Name': 'Product5',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1006': {'Name': 'Product6',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1007': {'Name': 'Product7',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1008': {'Name': 'Product8',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1009': {'Name': 'Product9',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1010': {'Name': 'Product10',
#   'MRP': 1500,
#   'Quantity': 8,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1011': {'Name': 'Product11',
#   'MRP': 100,
#   'Quantity': 30,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1012': {'Name': 'Product12',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1013': {'Name': 'Product13',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1014': {'Name': 'Product14',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1015': {'Name': 'Product15',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1016': {'Name': 'Product16',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1017': {'Name': 'Product17',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1018': {'Name': 'Product18',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1019': {'Name': 'Product19',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1020': {'Name': 'Product20',
#   'MRP': 1500,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1021': {'Name': 'Product21',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1022': {'Name': 'Product22',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1023': {'Name': 'Product23',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1024': {'Name': 'Product24',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1025': {'Name': 'Product25',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1026': {'Name': 'Product26',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1027': {'Name': 'Product27',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1028': {'Name': 'Product28',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1029': {'Name': 'Product29',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1030': {'Name': 'Product30',
#   'MRP': 1500,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1031': {'Name': 'Product31',
#   'MRP': 250,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1}}

# %%
#TO DELETE A PRODUCT RECORD

del records['1031']

# %%
records
# Out:
# {'1001': {'Name': 'Product1',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1002': {'Name': 'Product2',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1003': {'Name': 'Product3',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1004': {'Name': 'Product4',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1005': {'Name': 'Product5',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1006': {'Name': 'Product6',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1007': {'Name': 'Product7',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1008': {'Name': 'Product8',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1009': {'Name': 'Product9',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1010': {'Name': 'Product10',
#   'MRP': 1500,
#   'Quantity': 8,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1011': {'Name': 'Product11',
#   'MRP': 100,
#   'Quantity': 30,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1012': {'Name': 'Product12',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1013': {'Name': 'Product13',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1014': {'Name': 'Product14',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1015': {'Name': 'Product15',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1016': {'Name': 'Product16',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1017': {'Name': 'Product17',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1018': {'Name': 'Product18',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1019': {'Name': 'Product19',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1020': {'Name': 'Product20',
#   'MRP': 1500,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1021': {'Name': 'Product21',
#   'MRP': 100,
#   'Quantity': 34,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1022': {'Name': 'Product22',
#   'MRP': 800,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1023': {'Name': 'Product23',
#   'MRP': 85,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1024': {'Name': 'Product24',
#   'MRP': 5,
#   'Quantity': 1000,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1025': {'Name': 'Product25',
#   'MRP': 20,
#   'Quantity': 100,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1026': {'Name': 'Product26',
#   'MRP': 50000,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1027': {'Name': 'Product27',
#   'MRP': 1500,
#   'Quantity': 0,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1028': {'Name': 'Product28',
#   'MRP': 599,
#   'Quantity': 5,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1029': {'Name': 'Product29',
#   'MRP': 1999,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1},
#  '1030': {'Name': 'Product30',
#   'MRP': 1500,
#   'Quantity': 10,
#   'Category': 'Food',
#   'Minimum_Order': 1}}
